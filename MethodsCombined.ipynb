# %%
# !pip install pandas numpy matplotlib scikit-learn mord jupyter
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting mord
#   Downloading mord-0.7.tar.gz (8.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting notebook (from jupyter)
#   Downloading notebook-7.5.6-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in /home/codespace/.local/lib/python3.12/site-packages (from jupyter) (7.17.0)
# Requirement already satisfied: ipykernel in /home/codespace/.local/lib/python3.12/site-packages (from jupyter) (7.2.0)
# Collecting ipywidgets (from jupyter)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jupyterlab in /home/codespace/.local/lib/python3.12/site-packages (from jupyter) (4.5.5)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (9.11.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: decorator>=5.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: pexpect>4.6 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/codespace/.local/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter) (4.9.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.12/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->jupyter)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->jupyter)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: async-lru>=1.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab->jupyter) (82.0.1)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.12.1)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: typing_extensions>=4.5 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/codespace/.local/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/codespace/.local/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in /home/codespace/.local/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /home/codespace/.local/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in /home/codespace/.local/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2025.3)
# Collecting jupyterlab (from jupyter)
#   Downloading jupyterlab-4.5.7-py3-none-any.whl.metadata (16 kB)
# Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 42.9 MB/s  0:00:006m0:00:01
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 40.9 MB/s  0:00:006m0:00:01
# Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 49.4 MB/s  0:00:00
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 36.6 MB/s  0:00:006m0:00:01
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 48.2 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.5 MB/s  0:00:00
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 36.0 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 45.3 MB/s  0:00:006m0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 27.4 MB/s  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 33.4 MB/s  0:00:00
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading notebook-7.5.6-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 45.3 MB/s  0:00:006m0:00:01
# Downloading jupyterlab-4.5.7-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 26.8 MB/s  0:00:006m0:00:01
# Building wheels for collected packages: mord
#   Building wheel for mord (pyproject.toml) ... done
#   Created wheel for mord: filename=mord-0.7-py3-none-any.whl size=9953 sha256=af24612f4fa3f329449261dc662fc3936a9d0f88b6a331705816654de3879a65
#   Stored in directory: /home/codespace/.cache/pip/wheels/80/3e/3b/13f1adf346cad0fec675db328e4b0d814795c6c8e2fb659122
# Successfully built mord
# Installing collected packages: mord, widgetsnbextension, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, jupyterlab_widgets, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib, ipywidgets, jupyter-console, jupyterlab, notebook, jupyter
#   Attempting uninstall: jupyterlab━━╸━━━━━━━━━━━ 15/21 [matplotlib]n]
#     Found existing installation: jupyterlab 4.5.50m━━━━━━━━━━━ 15/21 [matplotlib]
#     Uninstalling jupyterlab-4.5.5:━━━━━━━━╺━━━━━ 18/21 [jupyterlab]
#       Successfully uninstalled jupyterlab-4.5.5╺━━━━━ 18/21 [jupyterlab]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [jupyter]9/21 [notebook]b]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 ipywidgets-8.1.8 joblib-1.5.3 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab-4.5.7 jupyterlab_widgets-3.0.16 kiwisolver-1.5.0 matplotlib-3.10.9 mord-0.7 notebook-7.5.6 numpy-2.4.6 pandas-3.0.3 pillow-12.2.0 pyparsing-3.3.2 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0 widgetsnbextension-4.0.15
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

from mord import LogisticAT


# =========================
# 1. LOAD DATA
# =========================

file_path = "Post Insights Sheet(Data).csv"
df = pd.read_csv(file_path)

print("Dataset shape:", df.shape)


# =========================
# 2. CREATE POSITION GROUPS
# =========================

position_map = {
    "QB": "Skill", "RB": "Skill", "FB": "Skill", "WR": "Skill", "TE": "Skill",
    "OT": "OL", "OG": "OL", "G": "OL", "C": "OL", "OC": "OL", "IOL": "OL", "OL": "OL",
    "EDGE": "DL", "DE": "DL", "DT": "DL", "DL": "DL",
    "LB": "LB", "ILB": "LB", "OLB": "LB",
    "CB": "Secondary", "S": "Secondary", "SAF": "Secondary", "DB": "Secondary",
    "K": "Special Teams", "P": "Special Teams", "LS": "Special Teams"
}

df["Position Group"] = df["Position"].map(position_map).fillna(df["Position"])


# =========================
# 3. CREATE ORDINAL DRAFT TIER TARGET
# =========================

def draft_tier(pick):
    if pick <= 32:
        return "Round 1"
    elif pick <= 96:
        return "Rounds 2-3"
    elif pick <= 160:
        return "Rounds 4-5"
    elif pick <= 262:
        return "Rounds 6-7"
    else:
        return "Undrafted"


df["Draft Tier"] = df["Overall Pick"].apply(draft_tier)

labels_order = [
    "Round 1",
    "Rounds 2-3",
    "Rounds 4-5",
    "Rounds 6-7",
    "Undrafted"
]

tier_to_num = {
    "Round 1": 0,
    "Rounds 2-3": 1,
    "Rounds 4-5": 2,
    "Rounds 6-7": 3,
    "Undrafted": 4
}

num_to_tier = {
    0: "Round 1",
    1: "Rounds 2-3",
    2: "Rounds 4-5",
    3: "Rounds 6-7",
    4: "Undrafted"
}

df["Draft Tier Ordinal"] = df["Draft Tier"].map(tier_to_num)

print("\nDraft Tier Counts:")
print(df["Draft Tier"].value_counts())


# =========================
# 4. FEATURES
# =========================

features = [
    "Season",
    "Position",
    "Position Group",
    "School",
    "Conference",
    "Height (inches)",
    "Weight(lbs)",
    "Hand (inches)",
    "Arm (inches)",
    "Wingspan (inches)",
    "40-Yard Dash (seconds)",
    "Vertical (inches)",
    "Bench (reps)",
    "Broad Jump (inches)",
    "3-Cone (seconds)",
    "Shuttle (seconds)",
    "Combine Participation",
    "ELO",
    "FPI",
    "Efficiencies Overall",
    "Efficiencies Offense",
    "Efficiencies Defense",
    "Efficiencies SpecialTeams",
    "CFP Appearance",
    "National Award"
]

combine_metrics = [
    "Height (inches)",
    "Weight(lbs)",
    "Hand (inches)",
    "Arm (inches)",
    "Wingspan (inches)",
    "40-Yard Dash (seconds)",
    "Vertical (inches)",
    "Bench (reps)",
    "Broad Jump (inches)",
    "3-Cone (seconds)",
    "Shuttle (seconds)"
]

# Basic model features
basic_features = [
    "Season",
    "Position",
    "Conference",
    "CFP Appearance"
]


# =========================
# 5. BUILD ORDINAL MODEL FUNCTION
# =========================

def build_model(feature_list):
    categorical_features = [
        col for col in ["Position", "Position Group", "School", "Conference"]
        if col in feature_list
    ]

    numeric_features = [
        col for col in feature_list if col not in categorical_features
    ]

    preprocessor = ColumnTransformer(
        transformers=[
            ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
            ("num", "passthrough", numeric_features)
        ]
    )

    model = Pipeline(
        steps=[
            ("preprocessor", preprocessor),
            ("ordinal_model", LogisticAT(alpha=1.0))
        ]
    )

    return model


# =========================
# 6. MANUAL ORDINAL PREDICTION REPORT
# =========================

def print_manual_report(y_true, y_pred, title):
    y_true_labels = pd.Series(y_true).map(num_to_tier)
    y_pred_labels = pd.Series(y_pred).map(num_to_tier)

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true_labels,
        y_pred_labels,
        labels=labels_order,
        zero_division=0
    )

    print(f"\n{title}")
    print(f"{'Tier':<14}{'Precision':>12}{'Recall':>12}{'F1-Score':>12}{'Support':>12}")

    for label, p, r, f, s in zip(labels_order, precision, recall, f1, support):
        print(f"{label:<14}{p:>12.2f}{r:>12.2f}{f:>12.2f}{s:>12}")

    print("\nAccuracy:", round(accuracy_score(y_true, y_pred), 4))

    ordinal_error = np.mean(np.abs(np.array(y_true) - np.array(y_pred)))
    print("Average Ordinal Error:", round(ordinal_error, 4))


# =========================
# 7. OVERALL ORDINAL MODEL
# =========================

X = df[features]
y = df["Draft Tier Ordinal"]

overall_model = build_model(features)

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_scores = cross_val_score(
    overall_model,
    X,
    y,
    cv=cv,
    scoring="accuracy"
)

print("\nOVERALL ORDINAL MODEL - 5-Fold CV Accuracy Scores:")
print(cv_scores)
print("Average CV Accuracy:", round(cv_scores.mean(), 4))
print("CV Accuracy Standard Deviation:", round(cv_scores.std(), 4))

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

overall_model.fit(X_train, y_train)
y_pred = overall_model.predict(X_test)

print_manual_report(
    y_test,
    y_pred,
    "OVERALL MODEL - Ordinal Prediction Report"
)


# =========================
# 8. BASIC MODEL FOR OVERALL GAINS CHARTS
# =========================

X_basic_full = df[basic_features]

X_train_basic = X_basic_full.loc[X_train.index]
X_test_basic = X_basic_full.loc[X_test.index]

overall_basic_model = build_model(basic_features)
overall_basic_model.fit(X_train_basic, y_train)

basic_probs_overall = overall_basic_model.predict_proba(X_test_basic)

basic_prob_df_overall = pd.DataFrame(
    basic_probs_overall,
    columns=labels_order
)


# =========================
# 9. OVERALL FEATURE COEFFICIENTS
# =========================

ordinal_model = overall_model.named_steps["ordinal_model"]
feature_names = overall_model.named_steps["preprocessor"].get_feature_names_out()

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": ordinal_model.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)

print("\nTop 20 Overall Features by Absolute Coefficient Size:")
print(importance_df.head(20).to_string(index=False))


# =========================
# 10. POSITION GROUP ORDINAL MODELS
# =========================

position_group_results = []
position_group_importances = []
group_model_store = {}

for group in df["Position Group"].dropna().unique():
    group_df = df[df["Position Group"] == group].copy()

    print("\n" + "=" * 70)
    print(f"POSITION GROUP ORDINAL MODEL: {group}")
    print("=" * 70)
    print("Rows:", len(group_df))
    print("Draft Tier Counts:")
    print(group_df["Draft Tier"].value_counts())

    if len(group_df) < 50 or group_df["Draft Tier Ordinal"].nunique() < 2:
        print("Skipped: not enough data or only one draft tier present.")
        continue

    group_features = [
        col for col in features if col != "Position Group"
    ]

    X_group = group_df[group_features]
    y_group = group_df["Draft Tier Ordinal"]

    min_class_count = y_group.value_counts().min()

    if min_class_count < 2:
        print("Skipped: at least one tier has fewer than 2 players.")
        continue

    n_splits = min(5, min_class_count)

    group_model = build_model(group_features)

    group_cv = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )

    group_cv_scores = cross_val_score(
        group_model,
        X_group,
        y_group,
        cv=group_cv,
        scoring="accuracy"
    )

    print(f"\n{n_splits}-Fold Stratified CV Accuracy Scores:")
    print(group_cv_scores)
    print("Average CV Accuracy:", round(group_cv_scores.mean(), 4))
    print("CV Accuracy Standard Deviation:", round(group_cv_scores.std(), 4))

    X_train_g, X_test_g, y_train_g, y_test_g = train_test_split(
        X_group,
        y_group,
        test_size=0.25,
        random_state=42,
        stratify=y_group
    )

    group_model.fit(X_train_g, y_train_g)
    y_pred_g = group_model.predict(X_test_g)

    print_manual_report(
        y_test_g,
        y_pred_g,
        f"{group} - Ordinal Prediction Report"
    )

    position_group_results.append({
        "Position Group": group,
        "Rows": len(group_df),
        "CV Accuracy Mean": group_cv_scores.mean(),
        "CV Accuracy Std": group_cv_scores.std(),
        "Test Accuracy": accuracy_score(y_test_g, y_pred_g),
        "Average Ordinal Error": np.mean(np.abs(np.array(y_test_g) - np.array(y_pred_g)))
    })

    ordinal_model_g = group_model.named_steps["ordinal_model"]
    feature_names_g = group_model.named_steps["preprocessor"].get_feature_names_out()

    importance_g = pd.DataFrame({
        "Feature": feature_names_g,
        "Coefficient": ordinal_model_g.coef_
    }).sort_values(by="Coefficient", key=abs, ascending=False)

    print(f"\nTop 15 Features for {group} by Absolute Coefficient Size:")
    print(importance_g.head(15).to_string(index=False))

    combine_group_importance = []

    for metric in combine_metrics:
        matching_rows = importance_g[
            importance_g["Feature"].str.contains(metric, regex=False)
        ]

        combine_group_importance.append({
            "Position Group": group,
            "Metric": metric,
            "Coefficient Strength": matching_rows["Coefficient"].abs().sum()
        })

    combine_group_df = pd.DataFrame(combine_group_importance).sort_values(
        by="Coefficient Strength",
        ascending=False
    )

    print(f"\nCombine Metric Coefficient Strength for {group}:")
    print(combine_group_df.to_string(index=False))

    position_group_importances.append(combine_group_df)

    # Basic model for this position group
    group_basic_features = [
        col for col in basic_features
        if col in group_df.columns
    ]

    X_group_basic = group_df[group_basic_features]
    X_train_gb = X_group_basic.loc[X_train_g.index]
    X_test_gb = X_group_basic.loc[X_test_g.index]

    group_basic_model = build_model(group_basic_features)
    group_basic_model.fit(X_train_gb, y_train_g)

    basic_probs_g = group_basic_model.predict_proba(X_test_gb)
    basic_prob_df_g = pd.DataFrame(
        basic_probs_g,
        columns=labels_order
    )

    full_probs_g = group_model.predict_proba(X_test_g)

    group_model_store[group] = {
        "full_prob_df": pd.DataFrame(full_probs_g, columns=labels_order),
        "basic_prob_df": basic_prob_df_g,
        "y_test": y_test_g,
        "X_test": X_test_g
    }


# =========================
# 11. SAVE POSITION GROUP SUMMARY
# =========================

position_group_results_df = pd.DataFrame(position_group_results)

print("\nPOSITION GROUP ORDINAL MODEL SUMMARY:")
print(position_group_results_df.to_string(index=False))

position_group_results_df.to_csv(
    "position_group_ordinal_model_summary_no_log_rank.csv",
    index=False
)

if position_group_importances:
    all_position_importances_df = pd.concat(
        position_group_importances,
        ignore_index=True
    )

    all_position_importances_df.to_csv(
        "position_group_combine_metric_coefficient_strength_no_log_rank.csv",
        index=False
    )


# =========================
# 12. GAINS CHART FUNCTION
# =========================

def plot_gains_chart(
    target_tier,
    gains_base_arg,
    prob_df_arg,
    basic_prob_df_arg=None,
    label_prefix=""
):
    temp_df = gains_base_arg.copy()

    temp_df["Actual Target"] = np.where(
        temp_df["Actual Draft Tier"] == target_tier,
        1,
        0
    )

    temp_df["Predicted Probability"] = prob_df_arg[target_tier].values

    temp_df = temp_df.sort_values(
        by="Predicted Probability",
        ascending=False
    ).reset_index(drop=True)

    total_actual_targets = temp_df["Actual Target"].sum()

    if total_actual_targets == 0:
        print(f"No actual {target_tier} players in this test set.")
        return None

    temp_df["Cumulative Actual Captured"] = temp_df["Actual Target"].cumsum()

    temp_df["Percent of Players Reviewed"] = (
        np.arange(1, len(temp_df) + 1) / len(temp_df)
    ) * 100

    temp_df["Percent of Actual Tier Captured"] = (
        temp_df["Cumulative Actual Captured"] / total_actual_targets
    ) * 100

    plt.figure(figsize=(10, 6))

    plt.plot(
        temp_df["Percent of Players Reviewed"],
        temp_df["Percent of Actual Tier Captured"],
        label=f"Ordinal Model: {target_tier}"
    )

    if basic_prob_df_arg is not None:
        actual_raw = (
            gains_base_arg["Actual Draft Tier"] == target_tier
        ).astype(int).values

        basic_col = basic_prob_df_arg[target_tier].values
        order_basic = np.argsort(-basic_col)

        cum_basic = (
            actual_raw[order_basic].cumsum()
            / total_actual_targets
            * 100
        )

        pct_x = (
            np.arange(1, len(actual_raw) + 1)
            / len(actual_raw)
            * 100
        )

        plt.plot(
            pct_x,
            cum_basic,
            linestyle="-.",
            label="Basic Model"
        )

    plt.plot(
        temp_df["Percent of Players Reviewed"],
        temp_df["Percent of Players Reviewed"],
        linestyle="--",
        label="Random Baseline"
    )

    title_prefix = f"{label_prefix}: " if label_prefix else ""

    plt.title(f"{title_prefix}Gains Chart: Predicting {target_tier} Players")
    plt.xlabel("Percent of Players Reviewed")
    plt.ylabel(f"Percent of Actual {target_tier} Players Captured")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return temp_df


# =========================
# 13. OVERALL GAINS CHARTS
# =========================

predicted_probs = overall_model.predict_proba(X_test)

prob_df = pd.DataFrame(
    predicted_probs,
    columns=labels_order
)

gains_base = X_test.copy().reset_index(drop=True)
gains_base["Actual Draft Tier"] = y_test.reset_index(drop=True).map(num_to_tier)

tier_outputs = {}

for tier in labels_order:
    print(f"\nCreating overall gains chart for: {tier}")

    tier_outputs[tier] = plot_gains_chart(
        target_tier=tier,
        gains_base_arg=gains_base,
        prob_df_arg=prob_df,
        basic_prob_df_arg=basic_prob_df_overall
    )

for tier, output_df in tier_outputs.items():
    if output_df is not None:
        clean_name = (
            tier.replace(" ", "_")
                .replace("-", "_")
                .replace("/", "_")
        )

        output_df.to_csv(
            f"gains_chart_{clean_name}_ordinal_no_log_rank.csv",
            index=False
        )


# =========================
# 14. POSITION GROUP GAINS CHARTS
# =========================

for group, store in group_model_store.items():
    print(f"\n--- Gains Charts: {group} ---")

    y_test_g_labels = pd.Series(store["y_test"]).reset_index(drop=True).map(num_to_tier)

    group_gains_base = store["X_test"].copy().reset_index(drop=True)
    group_gains_base["Actual Draft Tier"] = y_test_g_labels.values

    group_prob_df = store["full_prob_df"].reset_index(drop=True)
    group_basic_prob_df = store["basic_prob_df"].reset_index(drop=True)

    for tier in labels_order:
        print(f"Creating {group} gains chart for: {tier}")

        plot_gains_chart(
            target_tier=tier,
            gains_base_arg=group_gains_base,
            prob_df_arg=group_prob_df,
            basic_prob_df_arg=group_basic_prob_df,
            label_prefix=group
        )


print("\nDone. Ordinal models, coefficient tables, basic model, and gains charts saved.")
# Out:
# Dataset shape: (965, 27)
#
# Draft Tier Counts:
# Draft Tier
# Undrafted     264
# Rounds 6-7    230
# Rounds 2-3    189
# Rounds 4-5    186
# Round 1        96
# Name: count, dtype: int64
#
# OVERALL ORDINAL MODEL - 5-Fold CV Accuracy Scores:
# [0.2746114  0.25388601 0.25388601 0.27979275 0.27979275]
# Average CV Accuracy: 0.2684
# CV Accuracy Standard Deviation: 0.012
#
# OVERALL MODEL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.82        0.38        0.51          24
# Rounds 2-3            0.47        0.15        0.23          47
# Rounds 4-5            0.20        0.34        0.25          47
# Rounds 6-7            0.26        0.50        0.34          58
# Undrafted             0.50        0.18        0.27          66
#
# Accuracy: 0.3017
# Average Ordinal Error: 0.9587
#
# Top 20 Overall Features by Absolute Coefficient Size:
#                     Feature  Coefficient
#         num__National Award    -1.939641
#           num__Arm (inches)    -0.511696
#            cat__Position_OT    -0.448153
# num__40-Yard Dash (seconds)     0.439846
#            cat__Position_QB    -0.376157
#           cat__Position_IOL     0.308652
#     cat__Conference_Big Ten    -0.295844
#      cat__Conference_Pac-12    -0.232159
#      cat__Position Group_DL    -0.219494
#            cat__Position_RB     0.217335
#         cat__Conference_SEC     0.213143
#             cat__Position_C     0.206494
#          cat__Position_EDGE    -0.201986
#         cat__School_Alabama    -0.197455
#      cat__Position Group_LB     0.188258
#            cat__Position_LB     0.188258
#          num__Hand (inches)    -0.182298
#          cat__School_Oregon    -0.175343
#    cat__Conference_Sun Belt     0.168565
#            cat__Position_CB    -0.164121
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Skill
# ======================================================================
# Rows: 325
# Draft Tier Counts:
# Draft Tier
# Undrafted     92
# Rounds 6-7    86
# Rounds 2-3    57
# Rounds 4-5    57
# Round 1       33
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.27692308 0.29230769 0.26153846 0.18461538 0.21538462]
# Average CV Accuracy: 0.2462
# CV Accuracy Standard Deviation: 0.0401
#
# Skill - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               1.00        0.25        0.40           8
# Rounds 2-3            0.12        0.07        0.09          15
# Rounds 4-5            0.12        0.14        0.13          14
# Rounds 6-7            0.30        0.64        0.41          22
# Undrafted             0.22        0.09        0.12          23
#
# Accuracy: 0.2561
# Average Ordinal Error: 1.0366
#
# Top 15 Features for Skill by Absolute Coefficient Size:
#                    Feature  Coefficient
#        num__National Award    -1.066671
#           cat__Position_QB    -0.800622
#           cat__Position_WR     0.432749
#         num__Hand (inches)    -0.339926
#        num__CFP Appearance     0.300913
#          cat__School_Miami     0.295588
#          cat__School_Texas    -0.253049
#       cat__School_Michigan    -0.236679
#     cat__Conference_Pac-12    -0.231093
# num__Combine Participation     0.210313
#     cat__School_Texas Tech     0.196407
#     cat__Conference_Big 12    -0.185621
#       cat__School_Arkansas     0.183748
#           cat__Position_RB     0.165736
#      num__3-Cone (seconds)     0.162445
#
# Combine Metric Coefficient Strength for Skill:
# Position Group                 Metric  Coefficient Strength
#          Skill          Hand (inches)              0.339926
#          Skill       3-Cone (seconds)              0.162445
#          Skill      Wingspan (inches)              0.111463
#          Skill      Vertical (inches)              0.107480
#          Skill 40-Yard Dash (seconds)              0.097234
#          Skill    Broad Jump (inches)              0.068286
#          Skill      Shuttle (seconds)              0.050791
#          Skill           Arm (inches)              0.044489
#          Skill           Bench (reps)              0.030821
#          Skill        Height (inches)              0.026038
#          Skill            Weight(lbs)              0.015263
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Secondary
# ======================================================================
# Rows: 182
# Draft Tier Counts:
# Draft Tier
# Rounds 6-7    44
# Rounds 4-5    43
# Undrafted     42
# Rounds 2-3    41
# Round 1       12
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.27027027 0.37837838 0.27777778 0.19444444 0.25      ]
# Average CV Accuracy: 0.2742
# CV Accuracy Standard Deviation: 0.0597
#
# Secondary - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           3
# Rounds 2-3            0.31        0.40        0.35          10
# Rounds 4-5            0.33        0.18        0.24          11
# Rounds 6-7            0.11        0.18        0.14          11
# Undrafted             0.29        0.18        0.22          11
#
# Accuracy: 0.2174
# Average Ordinal Error: 1.0435
#
# Top 15 Features for Secondary by Absolute Coefficient Size:
#                    Feature  Coefficient
#        num__National Award    -2.682313
#        cat__Conference_SEC    -0.924925
# num__Combine Participation    -0.895554
#       cat__School_Ohio St.     0.826105
#      num__3-Cone (seconds)    -0.810283
#        cat__School_Georgia    -0.785778
#        cat__Conference_ACC    -0.777678
#     cat__Conference_Pac-12    -0.735853
#        num__CFP Appearance     0.718848
#       cat__School_Missouri    -0.682317
#         num__Hand (inches)    -0.640941
#          num__Arm (inches)     0.604849
#    cat__School_Florida St.    -0.600727
#      cat__School_Minnesota    -0.550913
#            cat__School_USC    -0.528903
#
# Combine Metric Coefficient Strength for Secondary:
# Position Group                 Metric  Coefficient Strength
#      Secondary       3-Cone (seconds)              0.810283
#      Secondary          Hand (inches)              0.640941
#      Secondary           Arm (inches)              0.604849
#      Secondary 40-Yard Dash (seconds)              0.444044
#      Secondary      Shuttle (seconds)              0.268369
#      Secondary      Wingspan (inches)              0.236026
#      Secondary      Vertical (inches)              0.204787
#      Secondary        Height (inches)              0.191418
#      Secondary           Bench (reps)              0.103021
#      Secondary    Broad Jump (inches)              0.073679
#      Secondary            Weight(lbs)              0.008488
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: DL
# ======================================================================
# Rows: 191
# Draft Tier Counts:
# Draft Tier
# Undrafted     48
# Rounds 2-3    44
# Rounds 4-5    39
# Rounds 6-7    34
# Round 1       26
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.30769231 0.36842105 0.23684211 0.21052632 0.34210526]
# Average CV Accuracy: 0.2931
# CV Accuracy Standard Deviation: 0.0605
#
# DL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               1.00        0.17        0.29           6
# Rounds 2-3            0.36        0.36        0.36          11
# Rounds 4-5            0.33        0.40        0.36          10
# Rounds 6-7            0.16        0.33        0.21           9
# Undrafted             0.20        0.08        0.12          12
#
# Accuracy: 0.2708
# Average Ordinal Error: 1.25
#
# Top 15 Features for DL by Absolute Coefficient Size:
#                         Feature  Coefficient
#             num__National Award    -2.404255
#     num__40-Yard Dash (seconds)     1.078134
#      num__Combine Participation    -0.813665
#              cat__Position_EDGE    -0.589017
#                cat__Position_DL     0.588534
# cat__Conference_FBS Independent     0.479456
#      cat__School_North Carolina     0.352917
#           cat__School_Tennessee    -0.339375
#             cat__Conference_MAC    -0.334499
#           cat__School_Texas A&M    -0.330247
#             num__CFP Appearance     0.316737
#              cat__School_Oregon    -0.293265
#             cat__School_Clemson    -0.288708
#          cat__School_Notre Dame     0.263974
#            cat__School_Arkansas     0.242366
#
# Combine Metric Coefficient Strength for DL:
# Position Group                 Metric  Coefficient Strength
#             DL 40-Yard Dash (seconds)              1.078134
#             DL       3-Cone (seconds)              0.223578
#             DL      Vertical (inches)              0.140753
#             DL          Hand (inches)              0.126735
#             DL           Arm (inches)              0.117610
#             DL        Height (inches)              0.107014
#             DL      Shuttle (seconds)              0.098240
#             DL      Wingspan (inches)              0.096046
#             DL    Broad Jump (inches)              0.058012
#             DL            Weight(lbs)              0.041810
#             DL           Bench (reps)              0.000320
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: OL
# ======================================================================
# Rows: 171
# Draft Tier Counts:
# Draft Tier
# Undrafted     48
# Rounds 6-7    43
# Rounds 2-3    34
# Rounds 4-5    24
# Round 1       22
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.17142857 0.32352941 0.29411765 0.26470588 0.20588235]
# Average CV Accuracy: 0.2519
# CV Accuracy Standard Deviation: 0.056
#
# OL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           5
# Rounds 2-3            0.29        0.22        0.25           9
# Rounds 4-5            0.11        0.33        0.16           6
# Rounds 6-7            0.40        0.36        0.38          11
# Undrafted             0.60        0.25        0.35          12
#
# Accuracy: 0.2558
# Average Ordinal Error: 1.093
#
# Top 15 Features for OL by Absolute Coefficient Size:
#                       Feature  Coefficient
#           num__National Award    -2.356966
#          cat__School_Michigan     0.795697
#    num__Combine Participation    -0.775414
#   num__40-Yard Dash (seconds)     0.629990
#            num__Hand (inches)    -0.584764
#               cat__School_LSU    -0.546057
#           cat__Conference_ACC    -0.505802
#              cat__School_Duke    -0.505340
#        num__Shuttle (seconds)     0.496657
# cat__Conference_Mountain West     0.451509
#             cat__Position_IOL     0.449230
#          cat__School_Penn St.    -0.442951
#           num__CFP Appearance    -0.441409
#          cat__School_Kentucky     0.427321
#         cat__School_Minnesota    -0.417483
#
# Combine Metric Coefficient Strength for OL:
# Position Group                 Metric  Coefficient Strength
#             OL 40-Yard Dash (seconds)              0.629990
#             OL          Hand (inches)              0.584764
#             OL      Shuttle (seconds)              0.496657
#             OL       3-Cone (seconds)              0.387601
#             OL           Arm (inches)              0.165147
#             OL      Wingspan (inches)              0.093867
#             OL        Height (inches)              0.063844
#             OL    Broad Jump (inches)              0.053117
#             OL      Vertical (inches)              0.046520
#             OL            Weight(lbs)              0.023732
#             OL           Bench (reps)              0.007753
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: LB
# ======================================================================
# Rows: 78
# Draft Tier Counts:
# Draft Tier
# Undrafted     25
# Rounds 4-5    20
# Rounds 6-7    17
# Rounds 2-3    13
# Round 1        3
# Name: count, dtype: int64
#
# 3-Fold Stratified CV Accuracy Scores:
# [0.42307692 0.26923077 0.26923077]
# Average CV Accuracy: 0.3205
# CV Accuracy Standard Deviation: 0.0725
#
# LB - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           1
# Rounds 2-3            0.00        0.00        0.00           3
# Rounds 4-5            0.38        0.60        0.46           5
# Rounds 6-7            0.33        0.50        0.40           4
# Undrafted             0.50        0.14        0.22           7
#
# Accuracy: 0.3
# Average Ordinal Error: 1.1
#
# Top 15 Features for LB by Absolute Coefficient Size:
#                       Feature  Coefficient
#            num__Hand (inches)    -1.281768
#         num__3-Cone (seconds)     0.944604
#           cat__School_Florida    -0.938239
#        num__Shuttle (seconds)    -0.900644
#           cat__School_Indiana     0.897283
#    cat__School_South Carolina     0.779892
#           cat__School_Rutgers     0.778740
#           cat__School_Clemson    -0.646554
#       cat__Conference_Big Ten     0.590902
#              cat__School_Duke     0.581210
#    cat__School_Washington St.    -0.578402
#           cat__Conference_AAC    -0.524335
#          cat__School_Missouri    -0.520463
#            cat__School_Tulane    -0.497923
# cat__Conference_Mountain West     0.474443
#
# Combine Metric Coefficient Strength for LB:
# Position Group                 Metric  Coefficient Strength
#             LB          Hand (inches)              1.281768
#             LB       3-Cone (seconds)              0.944604
#             LB      Shuttle (seconds)              0.900644
#             LB        Height (inches)              0.326416
#             LB 40-Yard Dash (seconds)              0.297304
#             LB      Wingspan (inches)              0.154755
#             LB    Broad Jump (inches)              0.127410
#             LB            Weight(lbs)              0.124915
#             LB           Bench (reps)              0.058862
#             LB           Arm (inches)              0.042391
#             LB      Vertical (inches)              0.009068
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Special Teams
# ======================================================================
# Rows: 18
# Draft Tier Counts:
# Draft Tier
# Undrafted     9
# Rounds 6-7    6
# Rounds 4-5    3
# Name: count, dtype: int64
# Skipped: not enough data or only one draft tier present.
#
# POSITION GROUP ORDINAL MODEL SUMMARY:
# Position Group  Rows  CV Accuracy Mean  CV Accuracy Std  Test Accuracy  Average Ordinal Error
#          Skill   325          0.246154         0.040118       0.256098               1.036585
#      Secondary   182          0.274174         0.059713       0.217391               1.043478
#             DL   191          0.293117         0.060450       0.270833               1.250000
#             OL   171          0.251933         0.055983       0.255814               1.093023
#             LB    78          0.320513         0.072524       0.300000               1.100000
#
# Creating overall gains chart for: Round 1
# Creating overall gains chart for: Rounds 2-3
# Creating overall gains chart for: Rounds 4-5
# Creating overall gains chart for: Rounds 6-7
# Creating overall gains chart for: Undrafted
# --- Gains Charts: Skill ---
# Creating Skill gains chart for: Round 1
# Creating Skill gains chart for: Rounds 2-3
# Creating Skill gains chart for: Rounds 4-5
# Creating Skill gains chart for: Rounds 6-7
# Creating Skill gains chart for: Undrafted
# --- Gains Charts: Secondary ---
# Creating Secondary gains chart for: Round 1
# Creating Secondary gains chart for: Rounds 2-3
# Creating Secondary gains chart for: Rounds 4-5
# Creating Secondary gains chart for: Rounds 6-7
# Creating Secondary gains chart for: Undrafted
# --- Gains Charts: DL ---
# Creating DL gains chart for: Round 1
# Creating DL gains chart for: Rounds 2-3
# Creating DL gains chart for: Rounds 4-5
# Creating DL gains chart for: Rounds 6-7
# Creating DL gains chart for: Undrafted
# --- Gains Charts: OL ---
# Creating OL gains chart for: Round 1
# Creating OL gains chart for: Rounds 2-3
# Creating OL gains chart for: Rounds 4-5
# Creating OL gains chart for: Rounds 6-7
# Creating OL gains chart for: Undrafted
# --- Gains Charts: LB ---
# Creating LB gains chart for: Round 1
# Creating LB gains chart for: Rounds 2-3
# Creating LB gains chart for: Rounds 4-5
# Creating LB gains chart for: Rounds 6-7
# Creating LB gains chart for: Undrafted
# Done. Ordinal models, coefficient tables, basic model, and gains charts saved.

# %%
ordinal_model = overall_model.named_steps["ordinal_model"]

print("Number of coefficients:", len(ordinal_model.coef_))
print("Number of thresholds:", len(ordinal_model.theta_))
# Out:
# Number of coefficients: 209
# Number of thresholds: 4

# %%
numeric_cols = [
    "Height (inches)",
    "Weight(lbs)",
    "Hand (inches)",
    "Arm (inches)",
    "Wingspan (inches)",
    "40-Yard Dash (seconds)",
    "Vertical (inches)",
    "Bench (reps)",
    "Broad Jump (inches)",
    "3-Cone (seconds)",
    "Shuttle (seconds)",
    "ELO",
    "FPI"
]

corr = df[numeric_cols].corr().round(2)
print(corr)
# Out:
#                         Height (inches)  Weight(lbs)  Hand (inches)  \
# Height (inches)                    1.00         0.59           0.40
# Weight(lbs)                        0.59         1.00           0.51
# Hand (inches)                      0.40         0.51           1.00
# Arm (inches)                       0.58         0.64           0.48
# Wingspan (inches)                  0.63         0.69           0.51
# 40-Yard Dash (seconds)             0.45         0.77           0.38
# Vertical (inches)                 -0.33        -0.57          -0.27
# Bench (reps)                       0.25         0.50           0.25
# Broad Jump (inches)               -0.31        -0.65          -0.32
# 3-Cone (seconds)                   0.31         0.59           0.27
# Shuttle (seconds)                  0.10         0.29           0.11
# ELO                               -0.01         0.05           0.04
# FPI                               -0.01         0.06           0.04
#
#                         Arm (inches)  Wingspan (inches)  \
# Height (inches)                 0.58               0.63
# Weight(lbs)                     0.64               0.69
# Hand (inches)                   0.48               0.51
# Arm (inches)                    1.00               0.90
# Wingspan (inches)               0.90               1.00
# 40-Yard Dash (seconds)          0.46               0.50
# Vertical (inches)              -0.31              -0.34
# Bench (reps)                    0.29               0.31
# Broad Jump (inches)            -0.31              -0.37
# 3-Cone (seconds)                0.35               0.37
# Shuttle (seconds)               0.21               0.21
# ELO                            -0.02               0.01
# FPI                            -0.01               0.02
#
#                         40-Yard Dash (seconds)  Vertical (inches)  \
# Height (inches)                           0.45              -0.33
# Weight(lbs)                               0.77              -0.57
# Hand (inches)                             0.38              -0.27
# Arm (inches)                              0.46              -0.31
# Wingspan (inches)                         0.50              -0.34
# 40-Yard Dash (seconds)                    1.00              -0.57
# Vertical (inches)                        -0.57               1.00
# Bench (reps)                              0.33              -0.24
# Broad Jump (inches)                      -0.57               0.57
# 3-Cone (seconds)                          0.52              -0.38
# Shuttle (seconds)                         0.30              -0.24
# ELO                                       0.03              -0.10
# FPI                                       0.03              -0.08
#
#                         Bench (reps)  Broad Jump (inches)  3-Cone (seconds)  \
# Height (inches)                 0.25                -0.31              0.31
# Weight(lbs)                     0.50                -0.65              0.59
# Hand (inches)                   0.25                -0.32              0.27
# Arm (inches)                    0.29                -0.31              0.35
# Wingspan (inches)               0.31                -0.37              0.37
# 40-Yard Dash (seconds)          0.33                -0.57              0.52
# Vertical (inches)              -0.24                 0.57             -0.38
# Bench (reps)                    1.00                -0.22              0.34
# Broad Jump (inches)            -0.22                 1.00             -0.49
# 3-Cone (seconds)                0.34                -0.49              1.00
# Shuttle (seconds)               0.14                -0.24              0.39
# ELO                             0.04                -0.07              0.04
# FPI                             0.06                -0.06              0.05
#
#                         Shuttle (seconds)   ELO   FPI
# Height (inches)                      0.10 -0.01 -0.01
# Weight(lbs)                          0.29  0.05  0.06
# Hand (inches)                        0.11  0.04  0.04
# Arm (inches)                         0.21 -0.02 -0.01
# Wingspan (inches)                    0.21  0.01  0.02
# 40-Yard Dash (seconds)               0.30  0.03  0.03
# Vertical (inches)                   -0.24 -0.10 -0.08
# Bench (reps)                         0.14  0.04  0.06
# Broad Jump (inches)                 -0.24 -0.07 -0.06
# 3-Cone (seconds)                     0.39  0.04  0.05
# Shuttle (seconds)                    1.00  0.01  0.02
# ELO                                  0.01  1.00  0.96
# FPI                                  0.02  0.96  1.00

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

from mord import LogisticAT


# =========================
# 1. LOAD DATA
# =========================

file_path = "Post Insights Sheet(Data).csv"
df = pd.read_csv(file_path)

print("Dataset shape:", df.shape)


# =========================
# 2. CREATE POSITION GROUPS
# =========================

position_map = {
    "QB": "Skill", "RB": "Skill", "FB": "Skill", "WR": "Skill", "TE": "Skill",
    "OT": "OL", "OG": "OL", "G": "OL", "C": "OL", "OC": "OL", "IOL": "OL", "OL": "OL",
    "EDGE": "DL", "DE": "DL", "DT": "DL", "DL": "DL",
    "LB": "LB", "ILB": "LB", "OLB": "LB",
    "CB": "Secondary", "S": "Secondary", "SAF": "Secondary", "DB": "Secondary",
    "K": "Special Teams", "P": "Special Teams", "LS": "Special Teams"
}

df["Position Group"] = df["Position"].map(position_map).fillna(df["Position"])


# =========================
# 3. CREATE ORDINAL DRAFT TIER TARGET
# =========================

def draft_tier(pick):
    if pick <= 32:
        return "Round 1"
    elif pick <= 96:
        return "Rounds 2-3"
    elif pick <= 160:
        return "Rounds 4-5"
    elif pick <= 262:
        return "Rounds 6-7"
    else:
        return "Undrafted"


df["Draft Tier"] = df["Overall Pick"].apply(draft_tier)

labels_order = [
    "Round 1",
    "Rounds 2-3",
    "Rounds 4-5",
    "Rounds 6-7",
    "Undrafted"
]

tier_to_num = {
    "Round 1": 0,
    "Rounds 2-3": 1,
    "Rounds 4-5": 2,
    "Rounds 6-7": 3,
    "Undrafted": 4
}

num_to_tier = {
    0: "Round 1",
    1: "Rounds 2-3",
    2: "Rounds 4-5",
    3: "Rounds 6-7",
    4: "Undrafted"
}

df["Draft Tier Ordinal"] = df["Draft Tier"].map(tier_to_num)

print("\nDraft Tier Counts:")
print(df["Draft Tier"].value_counts())


# =========================
# 4. FEATURES
# ELO and Arm (inches) removed
# =========================

features = [
    "Season",
    "Position",
    "Position Group",
    "School",
    "Conference",
    "Height (inches)",
    "Weight(lbs)",
    "Hand (inches)",
    "Wingspan (inches)",
    "40-Yard Dash (seconds)",
    "Vertical (inches)",
    "Bench (reps)",
    "Broad Jump (inches)",
    "3-Cone (seconds)",
    "Shuttle (seconds)",
    "Combine Participation",
    "FPI",
    "Efficiencies Overall",
    "Efficiencies Offense",
    "Efficiencies Defense",
    "Efficiencies SpecialTeams",
    "CFP Appearance",
    "National Award"
]

combine_metrics = [
    "Height (inches)",
    "Weight(lbs)",
    "Hand (inches)",
    "Wingspan (inches)",
    "40-Yard Dash (seconds)",
    "Vertical (inches)",
    "Bench (reps)",
    "Broad Jump (inches)",
    "3-Cone (seconds)",
    "Shuttle (seconds)"
]

basic_features = [
    "Season",
    "Position",
    "Conference",
    "CFP Appearance"
]


# =========================
# 5. BUILD ORDINAL MODEL FUNCTION
# =========================

def build_model(feature_list):
    categorical_features = [
        col for col in ["Position", "Position Group", "School", "Conference"]
        if col in feature_list
    ]

    numeric_features = [
        col for col in feature_list if col not in categorical_features
    ]

    preprocessor = ColumnTransformer(
        transformers=[
            ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
            ("num", "passthrough", numeric_features)
        ]
    )

    model = Pipeline(
        steps=[
            ("preprocessor", preprocessor),
            ("ordinal_model", LogisticAT(alpha=1.0))
        ]
    )

    return model


# =========================
# 6. MANUAL ORDINAL PREDICTION REPORT
# =========================

def print_manual_report(y_true, y_pred, title):
    y_true_labels = pd.Series(y_true).map(num_to_tier)
    y_pred_labels = pd.Series(y_pred).map(num_to_tier)

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true_labels,
        y_pred_labels,
        labels=labels_order,
        zero_division=0
    )

    print(f"\n{title}")
    print(f"{'Tier':<14}{'Precision':>12}{'Recall':>12}{'F1-Score':>12}{'Support':>12}")

    for label, p, r, f, s in zip(labels_order, precision, recall, f1, support):
        print(f"{label:<14}{p:>12.2f}{r:>12.2f}{f:>12.2f}{s:>12}")

    print("\nAccuracy:", round(accuracy_score(y_true, y_pred), 4))

    ordinal_error = np.mean(np.abs(np.array(y_true) - np.array(y_pred)))
    print("Average Ordinal Error:", round(ordinal_error, 4))


# =========================
# 7. OVERALL ORDINAL MODEL
# =========================

X = df[features]
y = df["Draft Tier Ordinal"]

overall_model = build_model(features)

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_scores = cross_val_score(
    overall_model,
    X,
    y,
    cv=cv,
    scoring="accuracy"
)

print("\nOVERALL ORDINAL MODEL - 5-Fold CV Accuracy Scores:")
print(cv_scores)
print("Average CV Accuracy:", round(cv_scores.mean(), 4))
print("CV Accuracy Standard Deviation:", round(cv_scores.std(), 4))

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

overall_model.fit(X_train, y_train)
y_pred = overall_model.predict(X_test)

print_manual_report(
    y_test,
    y_pred,
    "OVERALL MODEL - Ordinal Prediction Report"
)


# =========================
# 8. BASIC MODEL FOR OVERALL GAINS CHARTS
# =========================

X_basic_full = df[basic_features]

X_train_basic = X_basic_full.loc[X_train.index]
X_test_basic = X_basic_full.loc[X_test.index]

overall_basic_model = build_model(basic_features)
overall_basic_model.fit(X_train_basic, y_train)

basic_probs_overall = overall_basic_model.predict_proba(X_test_basic)

basic_prob_df_overall = pd.DataFrame(
    basic_probs_overall,
    columns=labels_order
)


# =========================
# 9. OVERALL FEATURE COEFFICIENTS
# =========================

ordinal_model = overall_model.named_steps["ordinal_model"]
feature_names = overall_model.named_steps["preprocessor"].get_feature_names_out()

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": ordinal_model.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)

print("\nTop 20 Overall Features by Absolute Coefficient Size:")
print(importance_df.head(20).to_string(index=False))


# =========================
# 10. POSITION GROUP ORDINAL MODELS
# =========================

position_group_results = []
position_group_importances = []
group_model_store = {}

for group in df["Position Group"].dropna().unique():
    group_df = df[df["Position Group"] == group].copy()

    print("\n" + "=" * 70)
    print(f"POSITION GROUP ORDINAL MODEL: {group}")
    print("=" * 70)
    print("Rows:", len(group_df))
    print("Draft Tier Counts:")
    print(group_df["Draft Tier"].value_counts())

    if len(group_df) < 50 or group_df["Draft Tier Ordinal"].nunique() < 2:
        print("Skipped: not enough data or only one draft tier present.")
        continue

    group_features = [
        col for col in features if col != "Position Group"
    ]

    X_group = group_df[group_features]
    y_group = group_df["Draft Tier Ordinal"]

    min_class_count = y_group.value_counts().min()

    if min_class_count < 2:
        print("Skipped: at least one tier has fewer than 2 players.")
        continue

    n_splits = min(5, min_class_count)

    group_model = build_model(group_features)

    group_cv = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )

    group_cv_scores = cross_val_score(
        group_model,
        X_group,
        y_group,
        cv=group_cv,
        scoring="accuracy"
    )

    print(f"\n{n_splits}-Fold Stratified CV Accuracy Scores:")
    print(group_cv_scores)
    print("Average CV Accuracy:", round(group_cv_scores.mean(), 4))
    print("CV Accuracy Standard Deviation:", round(group_cv_scores.std(), 4))

    X_train_g, X_test_g, y_train_g, y_test_g = train_test_split(
        X_group,
        y_group,
        test_size=0.25,
        random_state=42,
        stratify=y_group
    )

    group_model.fit(X_train_g, y_train_g)
    y_pred_g = group_model.predict(X_test_g)

    print_manual_report(
        y_test_g,
        y_pred_g,
        f"{group} - Ordinal Prediction Report"
    )

    position_group_results.append({
        "Position Group": group,
        "Rows": len(group_df),
        "CV Accuracy Mean": group_cv_scores.mean(),
        "CV Accuracy Std": group_cv_scores.std(),
        "Test Accuracy": accuracy_score(y_test_g, y_pred_g),
        "Average Ordinal Error": np.mean(np.abs(np.array(y_test_g) - np.array(y_pred_g)))
    })

    ordinal_model_g = group_model.named_steps["ordinal_model"]
    feature_names_g = group_model.named_steps["preprocessor"].get_feature_names_out()

    importance_g = pd.DataFrame({
        "Feature": feature_names_g,
        "Coefficient": ordinal_model_g.coef_
    }).sort_values(by="Coefficient", key=abs, ascending=False)

    print(f"\nTop 15 Features for {group} by Absolute Coefficient Size:")
    print(importance_g.head(15).to_string(index=False))

    combine_group_importance = []

    for metric in combine_metrics:
        matching_rows = importance_g[
            importance_g["Feature"].str.contains(metric, regex=False)
        ]

        combine_group_importance.append({
            "Position Group": group,
            "Metric": metric,
            "Coefficient Strength": matching_rows["Coefficient"].abs().sum()
        })

    combine_group_df = pd.DataFrame(combine_group_importance).sort_values(
        by="Coefficient Strength",
        ascending=False
    )

    print(f"\nCombine Metric Coefficient Strength for {group}:")
    print(combine_group_df.to_string(index=False))

    position_group_importances.append(combine_group_df)

    group_basic_features = [
        col for col in basic_features
        if col in group_df.columns
    ]

    X_group_basic = group_df[group_basic_features]
    X_train_gb = X_group_basic.loc[X_train_g.index]
    X_test_gb = X_group_basic.loc[X_test_g.index]

    group_basic_model = build_model(group_basic_features)
    group_basic_model.fit(X_train_gb, y_train_g)

    basic_probs_g = group_basic_model.predict_proba(X_test_gb)
    basic_prob_df_g = pd.DataFrame(
        basic_probs_g,
        columns=labels_order
    )

    full_probs_g = group_model.predict_proba(X_test_g)

    group_model_store[group] = {
        "full_prob_df": pd.DataFrame(full_probs_g, columns=labels_order),
        "basic_prob_df": basic_prob_df_g,
        "y_test": y_test_g,
        "X_test": X_test_g
    }


# =========================
# 11. SAVE POSITION GROUP SUMMARY
# =========================

position_group_results_df = pd.DataFrame(position_group_results)

print("\nPOSITION GROUP ORDINAL MODEL SUMMARY:")
print(position_group_results_df.to_string(index=False))

position_group_results_df.to_csv(
    "position_group_ordinal_model_summary_no_ELO_no_arm.csv",
    index=False
)

if position_group_importances:
    all_position_importances_df = pd.concat(
        position_group_importances,
        ignore_index=True
    )

    all_position_importances_df.to_csv(
        "position_group_combine_metric_coefficient_strength_no_ELO_no_arm.csv",
        index=False
    )


# =========================
# 12. GAINS CHART FUNCTION
# =========================

def plot_gains_chart(
    target_tier,
    gains_base_arg,
    prob_df_arg,
    basic_prob_df_arg=None,
    label_prefix=""
):
    temp_df = gains_base_arg.copy()

    temp_df["Actual Target"] = np.where(
        temp_df["Actual Draft Tier"] == target_tier,
        1,
        0
    )

    temp_df["Predicted Probability"] = prob_df_arg[target_tier].values

    temp_df = temp_df.sort_values(
        by="Predicted Probability",
        ascending=False
    ).reset_index(drop=True)

    total_actual_targets = temp_df["Actual Target"].sum()

    if total_actual_targets == 0:
        print(f"No actual {target_tier} players in this test set.")
        return None

    temp_df["Cumulative Actual Captured"] = temp_df["Actual Target"].cumsum()

    temp_df["Percent of Players Reviewed"] = (
        np.arange(1, len(temp_df) + 1) / len(temp_df)
    ) * 100

    temp_df["Percent of Actual Tier Captured"] = (
        temp_df["Cumulative Actual Captured"] / total_actual_targets
    ) * 100

    plt.figure(figsize=(10, 6))

    plt.plot(
        temp_df["Percent of Players Reviewed"],
        temp_df["Percent of Actual Tier Captured"],
        label=f"Ordinal Model: {target_tier}"
    )

    if basic_prob_df_arg is not None:
        actual_raw = (
            gains_base_arg["Actual Draft Tier"] == target_tier
        ).astype(int).values

        basic_col = basic_prob_df_arg[target_tier].values
        order_basic = np.argsort(-basic_col)

        cum_basic = (
            actual_raw[order_basic].cumsum()
            / total_actual_targets
            * 100
        )

        pct_x = (
            np.arange(1, len(actual_raw) + 1)
            / len(actual_raw)
            * 100
        )

        plt.plot(
            pct_x,
            cum_basic,
            linestyle="-.",
            label="Basic Model"
        )

    plt.plot(
        temp_df["Percent of Players Reviewed"],
        temp_df["Percent of Players Reviewed"],
        linestyle="--",
        label="Random Baseline"
    )

    title_prefix = f"{label_prefix}: " if label_prefix else ""

    plt.title(f"{title_prefix}Gains Chart: Predicting {target_tier} Players")
    plt.xlabel("Percent of Players Reviewed")
    plt.ylabel(f"Percent of Actual {target_tier} Players Captured")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return temp_df


# =========================
# 13. OVERALL GAINS CHARTS
# =========================

predicted_probs = overall_model.predict_proba(X_test)

prob_df = pd.DataFrame(
    predicted_probs,
    columns=labels_order
)

gains_base = X_test.copy().reset_index(drop=True)
gains_base["Actual Draft Tier"] = y_test.reset_index(drop=True).map(num_to_tier)

tier_outputs = {}

for tier in labels_order:
    print(f"\nCreating overall gains chart for: {tier}")

    tier_outputs[tier] = plot_gains_chart(
        target_tier=tier,
        gains_base_arg=gains_base,
        prob_df_arg=prob_df,
        basic_prob_df_arg=basic_prob_df_overall
    )

for tier, output_df in tier_outputs.items():
    if output_df is not None:
        clean_name = (
            tier.replace(" ", "_")
                .replace("-", "_")
                .replace("/", "_")
        )

        output_df.to_csv(
            f"gains_chart_{clean_name}_ordinal_no_ELO_no_arm.csv",
            index=False
        )


# =========================
# 14. POSITION GROUP GAINS CHARTS
# =========================

for group, store in group_model_store.items():
    print(f"\n--- Gains Charts: {group} ---")

    y_test_g_labels = pd.Series(store["y_test"]).reset_index(drop=True).map(num_to_tier)

    group_gains_base = store["X_test"].copy().reset_index(drop=True)
    group_gains_base["Actual Draft Tier"] = y_test_g_labels.values

    group_prob_df = store["full_prob_df"].reset_index(drop=True)
    group_basic_prob_df = store["basic_prob_df"].reset_index(drop=True)

    for tier in labels_order:
        print(f"Creating {group} gains chart for: {tier}")

        plot_gains_chart(
            target_tier=tier,
            gains_base_arg=group_gains_base,
            prob_df_arg=group_prob_df,
            basic_prob_df_arg=group_basic_prob_df,
            label_prefix=group
        )


# =========================
# 15. CHECK NUMBER OF COEFFICIENTS AND THRESHOLDS
# =========================

ordinal_model = overall_model.named_steps["ordinal_model"]

print("\nNumber of coefficients:", len(ordinal_model.coef_))
print("Number of thresholds:", len(ordinal_model.theta_))

print("\nDone. Ordinal models, coefficient tables, basic model, and gains charts saved.")
# Out:
# Dataset shape: (965, 27)
#
# Draft Tier Counts:
# Draft Tier
# Undrafted     264
# Rounds 6-7    230
# Rounds 2-3    189
# Rounds 4-5    186
# Round 1        96
# Name: count, dtype: int64
#
# OVERALL ORDINAL MODEL - 5-Fold CV Accuracy Scores:
# [0.28497409 0.2746114  0.26943005 0.2746114  0.28497409]
# Average CV Accuracy: 0.2777
# CV Accuracy Standard Deviation: 0.0062
#
# OVERALL MODEL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.86        0.25        0.39          24
# Rounds 2-3            0.39        0.15        0.22          47
# Rounds 4-5            0.23        0.38        0.29          47
# Rounds 6-7            0.28        0.59        0.38          58
# Undrafted             0.50        0.14        0.21          66
#
# Accuracy: 0.3058
# Average Ordinal Error: 0.9298
#
# Top 20 Overall Features by Absolute Coefficient Size:
#                           Feature  Coefficient
#               num__National Award    -1.784898
#                  cat__Position_OT    -0.455358
#       num__40-Yard Dash (seconds)     0.439147
#                  cat__Position_QB    -0.377655
#                 cat__Position_IOL     0.287768
#                  cat__Position_RB     0.236523
#               cat__School_Alabama    -0.229324
#                   cat__Position_C     0.210247
#           cat__Conference_Big Ten    -0.197930
#            cat__Conference_Pac-12    -0.189591
#        num__Combine Participation    -0.173487
# cat__Position Group_Special Teams     0.161874
#          cat__Conference_Sun Belt     0.159168
#            cat__Position Group_DL    -0.156172
#                 cat__School_Miami     0.150577
#              cat__School_Arkansas     0.149594
#                cat__Position_EDGE    -0.149353
#                cat__School_Oregon    -0.142504
#               cat__Conference_MAC    -0.140025
#               cat__Conference_AAC    -0.138116
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Skill
# ======================================================================
# Rows: 325
# Draft Tier Counts:
# Draft Tier
# Undrafted     92
# Rounds 6-7    86
# Rounds 2-3    57
# Rounds 4-5    57
# Round 1       33
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.21538462 0.32307692 0.27692308 0.16923077 0.21538462]
# Average CV Accuracy: 0.24
# CV Accuracy Standard Deviation: 0.0538
#
# Skill - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               1.00        0.12        0.22           8
# Rounds 2-3            0.00        0.00        0.00          15
# Rounds 4-5            0.17        0.29        0.22          14
# Rounds 6-7            0.26        0.41        0.32          22
# Undrafted             0.27        0.17        0.21          23
#
# Accuracy: 0.2195
# Average Ordinal Error: 1.0976
#
# Top 15 Features for Skill by Absolute Coefficient Size:
#                    Feature  Coefficient
#        num__National Award    -1.931169
#           cat__Position_QB    -1.303533
#          cat__School_Miami     0.782588
#       cat__School_Michigan    -0.669568
#        num__CFP Appearance     0.669445
#           cat__Position_WR     0.639698
#          cat__School_Texas    -0.620356
#     cat__School_Texas Tech     0.533346
#           cat__Position_RB     0.512070
#      num__3-Cone (seconds)     0.493488
#    cat__School_Boston Col.    -0.479642
#     cat__Conference_Pac-12    -0.479353
#       cat__School_Arkansas     0.463498
# cat__School_North Carolina    -0.451367
#      cat__School_Minnesota     0.448298
#
# Combine Metric Coefficient Strength for Skill:
# Position Group                 Metric  Coefficient Strength
#          Skill       3-Cone (seconds)              0.493488
#          Skill 40-Yard Dash (seconds)              0.328750
#          Skill      Vertical (inches)              0.119862
#          Skill      Shuttle (seconds)              0.086302
#          Skill      Wingspan (inches)              0.080368
#          Skill    Broad Jump (inches)              0.074437
#          Skill        Height (inches)              0.046806
#          Skill           Bench (reps)              0.032386
#          Skill            Weight(lbs)              0.017487
#          Skill          Hand (inches)              0.017430
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Secondary
# ======================================================================
# Rows: 182
# Draft Tier Counts:
# Draft Tier
# Rounds 6-7    44
# Rounds 4-5    43
# Undrafted     42
# Rounds 2-3    41
# Round 1       12
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.2972973  0.21621622 0.33333333 0.25       0.27777778]
# Average CV Accuracy: 0.2749
# CV Accuracy Standard Deviation: 0.04
#
# Secondary - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           3
# Rounds 2-3            0.50        0.50        0.50          10
# Rounds 4-5            0.27        0.27        0.27          11
# Rounds 6-7            0.17        0.27        0.21          11
# Undrafted             0.33        0.18        0.24          11
#
# Accuracy: 0.2826
# Average Ordinal Error: 0.9348
#
# Top 15 Features for Secondary by Absolute Coefficient Size:
#                     Feature  Coefficient
#         num__National Award    -3.315238
#         cat__School_Georgia    -1.085376
#       num__3-Cone (seconds)    -1.027103
#        cat__School_Ohio St.     1.020307
#         cat__Conference_SEC    -0.986811
#  num__Combine Participation    -0.863461
#          num__Hand (inches)    -0.759793
#        cat__School_Missouri    -0.754795
#      cat__School_Oregon St.     0.710843
#         num__CFP Appearance     0.704077
#         cat__Conference_ACC    -0.677485
#             cat__School_USC    -0.658550
#      cat__Conference_Pac-12    -0.648858
#     cat__School_Florida St.    -0.646838
# num__40-Yard Dash (seconds)     0.631248
#
# Combine Metric Coefficient Strength for Secondary:
# Position Group                 Metric  Coefficient Strength
#      Secondary       3-Cone (seconds)              1.027103
#      Secondary          Hand (inches)              0.759793
#      Secondary 40-Yard Dash (seconds)              0.631248
#      Secondary        Height (inches)              0.296826
#      Secondary      Vertical (inches)              0.165861
#      Secondary      Shuttle (seconds)              0.112862
#      Secondary      Wingspan (inches)              0.092218
#      Secondary    Broad Jump (inches)              0.069412
#      Secondary           Bench (reps)              0.040913
#      Secondary            Weight(lbs)              0.007815
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: DL
# ======================================================================
# Rows: 191
# Draft Tier Counts:
# Draft Tier
# Undrafted     48
# Rounds 2-3    44
# Rounds 4-5    39
# Rounds 6-7    34
# Round 1       26
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.41025641 0.34210526 0.28947368 0.28947368 0.34210526]
# Average CV Accuracy: 0.3347
# CV Accuracy Standard Deviation: 0.0445
#
# DL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               1.00        0.17        0.29           6
# Rounds 2-3            0.40        0.36        0.38          11
# Rounds 4-5            0.31        0.50        0.38          10
# Rounds 6-7            0.21        0.33        0.26           9
# Undrafted             0.29        0.17        0.21          12
#
# Accuracy: 0.3125
# Average Ordinal Error: 1.2083
#
# Top 15 Features for DL by Absolute Coefficient Size:
#                         Feature  Coefficient
#             num__National Award    -4.026951
#     num__40-Yard Dash (seconds)     1.612338
#      num__Combine Participation    -1.208903
#              cat__Position_EDGE    -0.855891
#                cat__Position_DL     0.855161
#             cat__Conference_MAC    -0.775758
#      cat__School_North Carolina     0.709251
#          cat__Conference_Big 12     0.632786
# cat__Conference_FBS Independent     0.550012
#         cat__Conference_Big Ten    -0.529728
#           cat__School_Tennessee    -0.522016
#            cat__School_Arkansas     0.500198
#            cat__School_Marshall    -0.493659
#           cat__School_Texas A&M    -0.493224
#             cat__School_Clemson    -0.490363
#
# Combine Metric Coefficient Strength for DL:
# Position Group                 Metric  Coefficient Strength
#             DL 40-Yard Dash (seconds)              1.612338
#             DL      Vertical (inches)              0.157001
#             DL          Hand (inches)              0.151028
#             DL        Height (inches)              0.137754
#             DL      Wingspan (inches)              0.088464
#             DL    Broad Jump (inches)              0.080787
#             DL       3-Cone (seconds)              0.066925
#             DL            Weight(lbs)              0.057588
#             DL      Shuttle (seconds)              0.050206
#             DL           Bench (reps)              0.001125
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: OL
# ======================================================================
# Rows: 171
# Draft Tier Counts:
# Draft Tier
# Undrafted     48
# Rounds 6-7    43
# Rounds 2-3    34
# Rounds 4-5    24
# Round 1       22
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.14285714 0.32352941 0.26470588 0.26470588 0.20588235]
# Average CV Accuracy: 0.2403
# CV Accuracy Standard Deviation: 0.0613
#
# OL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           5
# Rounds 2-3            0.11        0.11        0.11           9
# Rounds 4-5            0.00        0.00        0.00           6
# Rounds 6-7            0.32        0.64        0.42          11
# Undrafted             0.33        0.08        0.13          12
#
# Accuracy: 0.2093
# Average Ordinal Error: 1.2326
#
# Top 15 Features for OL by Absolute Coefficient Size:
#                       Feature  Coefficient
#           num__National Award    -3.271915
#    num__Combine Participation    -1.022855
#          cat__School_Michigan     0.939422
#               cat__School_LSU    -0.928931
#   num__40-Yard Dash (seconds)     0.850167
#            num__Hand (inches)    -0.804932
#              cat__School_Duke    -0.789470
#        num__Shuttle (seconds)     0.699654
#           cat__Conference_ACC    -0.682769
#          cat__School_Kentucky     0.674089
# cat__Conference_Mountain West     0.651691
#           cat__School_Florida     0.620552
#         cat__School_Minnesota    -0.611385
#          cat__Conference_MVFC    -0.598786
#           cat__School_Georgia    -0.596833
#
# Combine Metric Coefficient Strength for OL:
# Position Group                 Metric  Coefficient Strength
#             OL 40-Yard Dash (seconds)              0.850167
#             OL          Hand (inches)              0.804932
#             OL      Shuttle (seconds)              0.699654
#             OL       3-Cone (seconds)              0.595039
#             OL    Broad Jump (inches)              0.065158
#             OL      Vertical (inches)              0.034271
#             OL      Wingspan (inches)              0.032790
#             OL            Weight(lbs)              0.024313
#             OL        Height (inches)              0.022615
#             OL           Bench (reps)              0.004946
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: LB
# ======================================================================
# Rows: 78
# Draft Tier Counts:
# Draft Tier
# Undrafted     25
# Rounds 4-5    20
# Rounds 6-7    17
# Rounds 2-3    13
# Round 1        3
# Name: count, dtype: int64
#
# 3-Fold Stratified CV Accuracy Scores:
# [0.46153846 0.30769231 0.30769231]
# Average CV Accuracy: 0.359
# CV Accuracy Standard Deviation: 0.0725
#
# LB - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           1
# Rounds 2-3            0.00        0.00        0.00           3
# Rounds 4-5            0.29        0.40        0.33           5
# Rounds 6-7            0.50        0.50        0.50           4
# Undrafted             0.67        0.29        0.40           7
#
# Accuracy: 0.3
# Average Ordinal Error: 1.2
#
# Top 15 Features for LB by Absolute Coefficient Size:
#                    Feature  Coefficient
#         num__Hand (inches)    -1.536453
#      num__3-Cone (seconds)     1.140704
#        cat__School_Indiana     1.106075
#        cat__School_Florida    -1.084467
#     num__Shuttle (seconds)    -1.057607
# cat__School_South Carolina     0.976733
#        cat__School_Rutgers     0.905929
#        cat__School_Clemson    -0.807902
#           cat__School_Duke     0.738106
# cat__School_Washington St.    -0.722976
# num__Combine Participation     0.715852
#        cat__Conference_AAC    -0.678711
#    cat__Conference_Big Ten     0.620340
#       cat__School_Missouri    -0.608639
#        num__CFP Appearance    -0.602965
#
# Combine Metric Coefficient Strength for LB:
# Position Group                 Metric  Coefficient Strength
#             LB          Hand (inches)              1.536453
#             LB       3-Cone (seconds)              1.140704
#             LB      Shuttle (seconds)              1.057607
#             LB        Height (inches)              0.517539
#             LB 40-Yard Dash (seconds)              0.360849
#             LB    Broad Jump (inches)              0.150142
#             LB            Weight(lbs)              0.131723
#             LB      Wingspan (inches)              0.079765
#             LB           Bench (reps)              0.047581
#             LB      Vertical (inches)              0.040137
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Special Teams
# ======================================================================
# Rows: 18
# Draft Tier Counts:
# Draft Tier
# Undrafted     9
# Rounds 6-7    6
# Rounds 4-5    3
# Name: count, dtype: int64
# Skipped: not enough data or only one draft tier present.
#
# POSITION GROUP ORDINAL MODEL SUMMARY:
# Position Group  Rows  CV Accuracy Mean  CV Accuracy Std  Test Accuracy  Average Ordinal Error
#          Skill   325          0.240000         0.053824       0.219512               1.097561
#      Secondary   182          0.274925         0.039970       0.282609               0.934783
#             DL   191          0.334683         0.044518       0.312500               1.208333
#             OL   171          0.240336         0.061316       0.209302               1.232558
#             LB    78          0.358974         0.072524       0.300000               1.200000
#
# Creating overall gains chart for: Round 1
# Creating overall gains chart for: Rounds 2-3
# Creating overall gains chart for: Rounds 4-5
# Creating overall gains chart for: Rounds 6-7
# Creating overall gains chart for: Undrafted
# --- Gains Charts: Skill ---
# Creating Skill gains chart for: Round 1
# Creating Skill gains chart for: Rounds 2-3
# Creating Skill gains chart for: Rounds 4-5
# Creating Skill gains chart for: Rounds 6-7
# Creating Skill gains chart for: Undrafted
# --- Gains Charts: Secondary ---
# Creating Secondary gains chart for: Round 1
# Creating Secondary gains chart for: Rounds 2-3
# Creating Secondary gains chart for: Rounds 4-5
# Creating Secondary gains chart for: Rounds 6-7
# Creating Secondary gains chart for: Undrafted
# --- Gains Charts: DL ---
# Creating DL gains chart for: Round 1
# Creating DL gains chart for: Rounds 2-3
# Creating DL gains chart for: Rounds 4-5
# Creating DL gains chart for: Rounds 6-7
# Creating DL gains chart for: Undrafted
# --- Gains Charts: OL ---
# Creating OL gains chart for: Round 1
# Creating OL gains chart for: Rounds 2-3
# Creating OL gains chart for: Rounds 4-5
# Creating OL gains chart for: Rounds 6-7
# Creating OL gains chart for: Undrafted
# --- Gains Charts: LB ---
# Creating LB gains chart for: Round 1
# Creating LB gains chart for: Rounds 2-3
# Creating LB gains chart for: Rounds 4-5
# Creating LB gains chart for: Rounds 6-7
# Creating LB gains chart for: Undrafted
# Number of coefficients: 207
# Number of thresholds: 4
#
# Done. Ordinal models, coefficient tables, basic model, and gains charts saved.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

from mord import LogisticAT


# =========================
# 1. LOAD DATA
# =========================

file_path = "Post Insights Sheet(Data).csv"
df = pd.read_csv(file_path)

print("Dataset shape:", df.shape)


# =========================
# 2. CREATE POSITION GROUPS
# =========================

position_map = {
    "QB": "Skill", "RB": "Skill", "FB": "Skill", "WR": "Skill", "TE": "Skill",
    "OT": "OL", "OG": "OL", "G": "OL", "C": "OL", "OC": "OL", "IOL": "OL", "OL": "OL",
    "EDGE": "DL", "DE": "DL", "DT": "DL", "DL": "DL",
    "LB": "LB", "ILB": "LB", "OLB": "LB",
    "CB": "Secondary", "S": "Secondary", "SAF": "Secondary", "DB": "Secondary",
    "K": "Special Teams", "P": "Special Teams", "LS": "Special Teams"
}

df["Position Group"] = df["Position"].map(position_map).fillna(df["Position"])


# =========================
# 3. CREATE ORDINAL DRAFT TIER TARGET
# =========================

def draft_tier(pick):
    if pick <= 32:
        return "Round 1"
    elif pick <= 96:
        return "Rounds 2-3"
    elif pick <= 160:
        return "Rounds 4-5"
    elif pick <= 262:
        return "Rounds 6-7"
    else:
        return "Undrafted"


df["Draft Tier"] = df["Overall Pick"].apply(draft_tier)

labels_order = [
    "Round 1",
    "Rounds 2-3",
    "Rounds 4-5",
    "Rounds 6-7",
    "Undrafted"
]

tier_to_num = {
    "Round 1": 0,
    "Rounds 2-3": 1,
    "Rounds 4-5": 2,
    "Rounds 6-7": 3,
    "Undrafted": 4
}

num_to_tier = {
    0: "Round 1",
    1: "Rounds 2-3",
    2: "Rounds 4-5",
    3: "Rounds 6-7",
    4: "Undrafted"
}

df["Draft Tier Ordinal"] = df["Draft Tier"].map(tier_to_num)

print("\nDraft Tier Counts:")
print(df["Draft Tier"].value_counts())


# =========================
# 4. FEATURES
# ELO, Arm (inches), and School removed
# =========================

features = [
    "Season",
    "Position",
    "Position Group",
    "Conference",
    "Height (inches)",
    "Weight(lbs)",
    "Hand (inches)",
    "Wingspan (inches)",
    "40-Yard Dash (seconds)",
    "Vertical (inches)",
    "Bench (reps)",
    "Broad Jump (inches)",
    "3-Cone (seconds)",
    "Shuttle (seconds)",
    "Combine Participation",
    "FPI",
    "Efficiencies Overall",
    "Efficiencies Offense",
    "Efficiencies Defense",
    "Efficiencies SpecialTeams",
    "CFP Appearance",
    "National Award"
]

combine_metrics = [
    "Height (inches)",
    "Weight(lbs)",
    "Hand (inches)",
    "Wingspan (inches)",
    "40-Yard Dash (seconds)",
    "Vertical (inches)",
    "Bench (reps)",
    "Broad Jump (inches)",
    "3-Cone (seconds)",
    "Shuttle (seconds)"
]

basic_features = [
    "Season",
    "Position",
    "Conference",
    "CFP Appearance"
]


# =========================
# 5. BUILD ORDINAL MODEL FUNCTION
# =========================

def build_model(feature_list):
    categorical_features = [
        col for col in ["Position", "Position Group", "Conference"]
        if col in feature_list
    ]

    numeric_features = [
        col for col in feature_list if col not in categorical_features
    ]

    preprocessor = ColumnTransformer(
        transformers=[
            ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
            ("num", "passthrough", numeric_features)
        ]
    )

    model = Pipeline(
        steps=[
            ("preprocessor", preprocessor),
            ("ordinal_model", LogisticAT(alpha=1.0))
        ]
    )

    return model


# =========================
# 6. MANUAL ORDINAL PREDICTION REPORT
# =========================

def print_manual_report(y_true, y_pred, title):
    y_true_labels = pd.Series(y_true).map(num_to_tier)
    y_pred_labels = pd.Series(y_pred).map(num_to_tier)

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true_labels,
        y_pred_labels,
        labels=labels_order,
        zero_division=0
    )

    print(f"\n{title}")
    print(f"{'Tier':<14}{'Precision':>12}{'Recall':>12}{'F1-Score':>12}{'Support':>12}")

    for label, p, r, f, s in zip(labels_order, precision, recall, f1, support):
        print(f"{label:<14}{p:>12.2f}{r:>12.2f}{f:>12.2f}{s:>12}")

    print("\nAccuracy:", round(accuracy_score(y_true, y_pred), 4))

    ordinal_error = np.mean(np.abs(np.array(y_true) - np.array(y_pred)))
    print("Average Ordinal Error:", round(ordinal_error, 4))


# =========================
# 7. OVERALL ORDINAL MODEL
# =========================

X = df[features]
y = df["Draft Tier Ordinal"]

overall_model = build_model(features)

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_scores = cross_val_score(
    overall_model,
    X,
    y,
    cv=cv,
    scoring="accuracy"
)

print("\nOVERALL ORDINAL MODEL - 5-Fold CV Accuracy Scores:")
print(cv_scores)
print("Average CV Accuracy:", round(cv_scores.mean(), 4))
print("CV Accuracy Standard Deviation:", round(cv_scores.std(), 4))

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

overall_model.fit(X_train, y_train)
y_pred = overall_model.predict(X_test)

print_manual_report(
    y_test,
    y_pred,
    "OVERALL MODEL - Ordinal Prediction Report"
)


# =========================
# 8. BASIC MODEL FOR OVERALL GAINS CHARTS
# =========================

X_basic_full = df[basic_features]

X_train_basic = X_basic_full.loc[X_train.index]
X_test_basic = X_basic_full.loc[X_test.index]

overall_basic_model = build_model(basic_features)
overall_basic_model.fit(X_train_basic, y_train)

basic_probs_overall = overall_basic_model.predict_proba(X_test_basic)

basic_prob_df_overall = pd.DataFrame(
    basic_probs_overall,
    columns=labels_order
)


# =========================
# 9. OVERALL FEATURE COEFFICIENTS
# =========================

ordinal_model = overall_model.named_steps["ordinal_model"]
feature_names = overall_model.named_steps["preprocessor"].get_feature_names_out()

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": ordinal_model.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)

print("\nTop 20 Overall Features by Absolute Coefficient Size:")
print(importance_df.head(20).to_string(index=False))


# =========================
# 10. POSITION GROUP ORDINAL MODELS
# =========================

position_group_results = []
position_group_importances = []
group_model_store = {}

for group in df["Position Group"].dropna().unique():
    group_df = df[df["Position Group"] == group].copy()

    print("\n" + "=" * 70)
    print(f"POSITION GROUP ORDINAL MODEL: {group}")
    print("=" * 70)
    print("Rows:", len(group_df))
    print("Draft Tier Counts:")
    print(group_df["Draft Tier"].value_counts())

    if len(group_df) < 50 or group_df["Draft Tier Ordinal"].nunique() < 2:
        print("Skipped: not enough data or only one draft tier present.")
        continue

    group_features = [
        col for col in features if col != "Position Group"
    ]

    X_group = group_df[group_features]
    y_group = group_df["Draft Tier Ordinal"]

    min_class_count = y_group.value_counts().min()

    if min_class_count < 2:
        print("Skipped: at least one tier has fewer than 2 players.")
        continue

    n_splits = min(5, min_class_count)

    group_model = build_model(group_features)

    group_cv = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )

    group_cv_scores = cross_val_score(
        group_model,
        X_group,
        y_group,
        cv=group_cv,
        scoring="accuracy"
    )

    print(f"\n{n_splits}-Fold Stratified CV Accuracy Scores:")
    print(group_cv_scores)
    print("Average CV Accuracy:", round(group_cv_scores.mean(), 4))
    print("CV Accuracy Standard Deviation:", round(group_cv_scores.std(), 4))

    X_train_g, X_test_g, y_train_g, y_test_g = train_test_split(
        X_group,
        y_group,
        test_size=0.25,
        random_state=42,
        stratify=y_group
    )

    group_model.fit(X_train_g, y_train_g)
    y_pred_g = group_model.predict(X_test_g)

    print_manual_report(
        y_test_g,
        y_pred_g,
        f"{group} - Ordinal Prediction Report"
    )

    position_group_results.append({
        "Position Group": group,
        "Rows": len(group_df),
        "CV Accuracy Mean": group_cv_scores.mean(),
        "CV Accuracy Std": group_cv_scores.std(),
        "Test Accuracy": accuracy_score(y_test_g, y_pred_g),
        "Average Ordinal Error": np.mean(np.abs(np.array(y_test_g) - np.array(y_pred_g)))
    })

    ordinal_model_g = group_model.named_steps["ordinal_model"]
    feature_names_g = group_model.named_steps["preprocessor"].get_feature_names_out()

    importance_g = pd.DataFrame({
        "Feature": feature_names_g,
        "Coefficient": ordinal_model_g.coef_
    }).sort_values(by="Coefficient", key=abs, ascending=False)

    print(f"\nTop 15 Features for {group} by Absolute Coefficient Size:")
    print(importance_g.head(15).to_string(index=False))

    combine_group_importance = []

    for metric in combine_metrics:
        matching_rows = importance_g[
            importance_g["Feature"].str.contains(metric, regex=False)
        ]

        combine_group_importance.append({
            "Position Group": group,
            "Metric": metric,
            "Coefficient Strength": matching_rows["Coefficient"].abs().sum()
        })

    combine_group_df = pd.DataFrame(combine_group_importance).sort_values(
        by="Coefficient Strength",
        ascending=False
    )

    print(f"\nCombine Metric Coefficient Strength for {group}:")
    print(combine_group_df.to_string(index=False))

    position_group_importances.append(combine_group_df)

    group_basic_features = [
        col for col in basic_features
        if col in group_df.columns
    ]

    X_group_basic = group_df[group_basic_features]
    X_train_gb = X_group_basic.loc[X_train_g.index]
    X_test_gb = X_group_basic.loc[X_test_g.index]

    group_basic_model = build_model(group_basic_features)
    group_basic_model.fit(X_train_gb, y_train_g)

    basic_probs_g = group_basic_model.predict_proba(X_test_gb)
    basic_prob_df_g = pd.DataFrame(
        basic_probs_g,
        columns=labels_order
    )

    full_probs_g = group_model.predict_proba(X_test_g)

    group_model_store[group] = {
        "full_prob_df": pd.DataFrame(full_probs_g, columns=labels_order),
        "basic_prob_df": basic_prob_df_g,
        "y_test": y_test_g,
        "X_test": X_test_g
    }


# =========================
# 11. SAVE POSITION GROUP SUMMARY
# =========================

position_group_results_df = pd.DataFrame(position_group_results)

print("\nPOSITION GROUP ORDINAL MODEL SUMMARY:")
print(position_group_results_df.to_string(index=False))

position_group_results_df.to_csv(
    "position_group_ordinal_model_summary_no_ELO_no_arm_no_school.csv",
    index=False
)

if position_group_importances:
    all_position_importances_df = pd.concat(
        position_group_importances,
        ignore_index=True
    )

    all_position_importances_df.to_csv(
        "position_group_combine_metric_coefficient_strength_no_ELO_no_arm_no_school.csv",
        index=False
    )


# =========================
# 12. GAINS CHART FUNCTION
# =========================

def plot_gains_chart(
    target_tier,
    gains_base_arg,
    prob_df_arg,
    basic_prob_df_arg=None,
    label_prefix=""
):
    temp_df = gains_base_arg.copy()

    temp_df["Actual Target"] = np.where(
        temp_df["Actual Draft Tier"] == target_tier,
        1,
        0
    )

    temp_df["Predicted Probability"] = prob_df_arg[target_tier].values

    temp_df = temp_df.sort_values(
        by="Predicted Probability",
        ascending=False
    ).reset_index(drop=True)

    total_actual_targets = temp_df["Actual Target"].sum()

    if total_actual_targets == 0:
        print(f"No actual {target_tier} players in this test set.")
        return None

    temp_df["Cumulative Actual Captured"] = temp_df["Actual Target"].cumsum()

    temp_df["Percent of Players Reviewed"] = (
        np.arange(1, len(temp_df) + 1) / len(temp_df)
    ) * 100

    temp_df["Percent of Actual Tier Captured"] = (
        temp_df["Cumulative Actual Captured"] / total_actual_targets
    ) * 100

    plt.figure(figsize=(10, 6))

    plt.plot(
        temp_df["Percent of Players Reviewed"],
        temp_df["Percent of Actual Tier Captured"],
        label=f"Ordinal Model: {target_tier}"
    )

    if basic_prob_df_arg is not None:
        actual_raw = (
            gains_base_arg["Actual Draft Tier"] == target_tier
        ).astype(int).values

        basic_col = basic_prob_df_arg[target_tier].values
        order_basic = np.argsort(-basic_col)

        cum_basic = (
            actual_raw[order_basic].cumsum()
            / total_actual_targets
            * 100
        )

        pct_x = (
            np.arange(1, len(actual_raw) + 1)
            / len(actual_raw)
            * 100
        )

        plt.plot(
            pct_x,
            cum_basic,
            linestyle="-.",
            label="Basic Model"
        )

    plt.plot(
        temp_df["Percent of Players Reviewed"],
        temp_df["Percent of Players Reviewed"],
        linestyle="--",
        label="Random Baseline"
    )

    title_prefix = f"{label_prefix}: " if label_prefix else ""

    plt.title(f"{title_prefix}Gains Chart: Predicting {target_tier} Players")
    plt.xlabel("Percent of Players Reviewed")
    plt.ylabel(f"Percent of Actual {target_tier} Players Captured")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return temp_df


# =========================
# 13. OVERALL GAINS CHARTS
# =========================

predicted_probs = overall_model.predict_proba(X_test)

prob_df = pd.DataFrame(
    predicted_probs,
    columns=labels_order
)

gains_base = X_test.copy().reset_index(drop=True)
gains_base["Actual Draft Tier"] = y_test.reset_index(drop=True).map(num_to_tier)

tier_outputs = {}

for tier in labels_order:
    print(f"\nCreating overall gains chart for: {tier}")

    tier_outputs[tier] = plot_gains_chart(
        target_tier=tier,
        gains_base_arg=gains_base,
        prob_df_arg=prob_df,
        basic_prob_df_arg=basic_prob_df_overall
    )

for tier, output_df in tier_outputs.items():
    if output_df is not None:
        clean_name = (
            tier.replace(" ", "_")
                .replace("-", "_")
                .replace("/", "_")
        )

        output_df.to_csv(
            f"gains_chart_{clean_name}_ordinal_no_ELO_no_arm_no_school.csv",
            index=False
        )


# =========================
# 14. POSITION GROUP GAINS CHARTS
# =========================

for group, store in group_model_store.items():
    print(f"\n--- Gains Charts: {group} ---")

    y_test_g_labels = pd.Series(store["y_test"]).reset_index(drop=True).map(num_to_tier)

    group_gains_base = store["X_test"].copy().reset_index(drop=True)
    group_gains_base["Actual Draft Tier"] = y_test_g_labels.values

    group_prob_df = store["full_prob_df"].reset_index(drop=True)
    group_basic_prob_df = store["basic_prob_df"].reset_index(drop=True)

    for tier in labels_order:
        print(f"Creating {group} gains chart for: {tier}")

        plot_gains_chart(
            target_tier=tier,
            gains_base_arg=group_gains_base,
            prob_df_arg=group_prob_df,
            basic_prob_df_arg=group_basic_prob_df,
            label_prefix=group
        )


# =========================
# 15. CHECK NUMBER OF COEFFICIENTS AND THRESHOLDS
# =========================

ordinal_model = overall_model.named_steps["ordinal_model"]

print("\nNumber of coefficients:", len(ordinal_model.coef_))
print("Number of thresholds:", len(ordinal_model.theta_))

print("\nDone. Ordinal models, coefficient tables, basic model, and gains charts saved.")
# Out:
# Dataset shape: (965, 27)
#
# Draft Tier Counts:
# Draft Tier
# Undrafted     264
# Rounds 6-7    230
# Rounds 2-3    189
# Rounds 4-5    186
# Round 1        96
# Name: count, dtype: int64
#
# OVERALL ORDINAL MODEL - 5-Fold CV Accuracy Scores:
# [0.31088083 0.28497409 0.27979275 0.30051813 0.28497409]
# Average CV Accuracy: 0.2922
# CV Accuracy Standard Deviation: 0.0116
#
# OVERALL MODEL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.79        0.46        0.58          24
# Rounds 2-3            0.46        0.13        0.20          47
# Rounds 4-5            0.18        0.26        0.21          47
# Rounds 6-7            0.25        0.55        0.35          58
# Undrafted             0.52        0.17        0.25          66
#
# Accuracy: 0.2975
# Average Ordinal Error: 0.9339
#
# Top 20 Overall Features by Absolute Coefficient Size:
#                           Feature  Coefficient
#               num__National Award    -2.263873
#                  cat__Position_OT    -0.561947
#       num__40-Yard Dash (seconds)     0.541002
#                  cat__Position_QB    -0.465702
#                 cat__Position_IOL     0.366612
#           cat__Conference_Big Ten    -0.299638
#                  cat__Position_RB     0.285449
#                   cat__Position_C     0.266457
#            cat__Conference_Pac-12    -0.257322
#            cat__Position Group_DL    -0.229680
#                cat__Position_EDGE    -0.212246
# cat__Position Group_Special Teams     0.198815
#          cat__Conference_Sun Belt     0.193509
#        num__Combine Participation    -0.187023
#                  cat__Position_CB    -0.178402
#               cat__Conference_MAC    -0.171845
#                num__Hand (inches)    -0.169664
#               cat__Conference_AAC    -0.165041
#            cat__Position Group_LB     0.165036
#                  cat__Position_LB     0.165036
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Skill
# ======================================================================
# Rows: 325
# Draft Tier Counts:
# Draft Tier
# Undrafted     92
# Rounds 6-7    86
# Rounds 2-3    57
# Rounds 4-5    57
# Round 1       33
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.23076923 0.30769231 0.23076923 0.23076923 0.24615385]
# Average CV Accuracy: 0.2492
# CV Accuracy Standard Deviation: 0.0298
#
# Skill - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               1.00        0.25        0.40           8
# Rounds 2-3            0.12        0.07        0.09          15
# Rounds 4-5            0.21        0.36        0.26          14
# Rounds 6-7            0.29        0.45        0.35          22
# Undrafted             0.23        0.13        0.17          23
#
# Accuracy: 0.2561
# Average Ordinal Error: 1.0732
#
# Top 15 Features for Skill by Absolute Coefficient Size:
#                         Feature  Coefficient
#             num__National Award    -1.540527
#                cat__Position_QB    -1.064562
#             num__CFP Appearance     0.551115
#                cat__Position_WR     0.528514
#          cat__Conference_Pac-12    -0.412065
#                cat__Position_RB     0.387362
#           num__3-Cone (seconds)     0.380246
#             cat__Conference_CAA     0.320959
#             cat__Conference_MAC    -0.294946
#          cat__Conference_Big 12    -0.291090
#     num__40-Yard Dash (seconds)     0.262845
# cat__Conference_FBS Independent     0.252585
#        cat__Conference_Sun Belt     0.251936
#  cat__Conference_Patriot League     0.227847
#            cat__Conference_MVFC     0.226367
#
# Combine Metric Coefficient Strength for Skill:
# Position Group                 Metric  Coefficient Strength
#          Skill       3-Cone (seconds)              0.380246
#          Skill 40-Yard Dash (seconds)              0.262845
#          Skill      Wingspan (inches)              0.143677
#          Skill          Hand (inches)              0.085137
#          Skill      Vertical (inches)              0.083071
#          Skill    Broad Jump (inches)              0.072473
#          Skill      Shuttle (seconds)              0.069544
#          Skill           Bench (reps)              0.027576
#          Skill        Height (inches)              0.023418
#          Skill            Weight(lbs)              0.015178
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Secondary
# ======================================================================
# Rows: 182
# Draft Tier Counts:
# Draft Tier
# Rounds 6-7    44
# Rounds 4-5    43
# Undrafted     42
# Rounds 2-3    41
# Round 1       12
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.18918919 0.37837838 0.36111111 0.22222222 0.38888889]
# Average CV Accuracy: 0.308
# CV Accuracy Standard Deviation: 0.0846
#
# Secondary - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           3
# Rounds 2-3            0.36        0.40        0.38          10
# Rounds 4-5            0.43        0.55        0.48          11
# Rounds 6-7            0.15        0.18        0.17          11
# Undrafted             0.29        0.18        0.22          11
#
# Accuracy: 0.3043
# Average Ordinal Error: 0.9348
#
# Top 15 Features for Secondary by Absolute Coefficient Size:
#                         Feature  Coefficient
#             num__National Award    -2.507495
#      num__Combine Participation    -0.745128
#           num__3-Cone (seconds)    -0.730966
#             cat__Conference_SEC    -0.727037
#             cat__Conference_ACC    -0.561574
#              num__Hand (inches)    -0.540608
#     num__40-Yard Dash (seconds)     0.522755
#          cat__Conference_Pac-12    -0.518585
#             num__CFP Appearance     0.430707
#            cat__Conference_CIAA     0.414138
#          cat__Conference_Big 12     0.399868
#            num__Height (inches)     0.334601
#   cat__Conference_Mountain West     0.310220
#             cat__Conference_CAA     0.274118
# cat__Conference_FBS Independent    -0.259489
#
# Combine Metric Coefficient Strength for Secondary:
# Position Group                 Metric  Coefficient Strength
#      Secondary       3-Cone (seconds)              0.730966
#      Secondary          Hand (inches)              0.540608
#      Secondary 40-Yard Dash (seconds)              0.522755
#      Secondary        Height (inches)              0.334601
#      Secondary      Vertical (inches)              0.147357
#      Secondary      Shuttle (seconds)              0.085538
#      Secondary      Wingspan (inches)              0.083736
#      Secondary           Bench (reps)              0.081672
#      Secondary    Broad Jump (inches)              0.057388
#      Secondary            Weight(lbs)              0.002982
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: DL
# ======================================================================
# Rows: 191
# Draft Tier Counts:
# Draft Tier
# Undrafted     48
# Rounds 2-3    44
# Rounds 4-5    39
# Rounds 6-7    34
# Round 1       26
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.30769231 0.36842105 0.34210526 0.31578947 0.31578947]
# Average CV Accuracy: 0.33
# CV Accuracy Standard Deviation: 0.0225
#
# DL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.25        0.17        0.20           6
# Rounds 2-3            0.00        0.00        0.00          11
# Rounds 4-5            0.24        0.40        0.30          10
# Rounds 6-7            0.12        0.22        0.16           9
# Undrafted             0.29        0.17        0.21          12
#
# Accuracy: 0.1875
# Average Ordinal Error: 1.375
#
# Top 15 Features for DL by Absolute Coefficient Size:
#                         Feature  Coefficient
#             num__National Award    -2.985901
#     num__40-Yard Dash (seconds)     1.255470
#      num__Combine Participation    -0.796524
#              cat__Position_EDGE    -0.772781
#                cat__Position_DL     0.772367
#         cat__Conference_Big Ten    -0.697695
#             cat__Conference_MAC    -0.488125
#          cat__Conference_Big 12     0.415223
# cat__Conference_FBS Independent     0.409019
#             cat__Conference_ACC     0.319620
#           num__3-Cone (seconds)     0.308701
#   cat__Conference_Mountain West    -0.242787
#             cat__Conference_SEC     0.204707
#          num__Shuttle (seconds)     0.199412
#              num__Hand (inches)     0.196581
#
# Combine Metric Coefficient Strength for DL:
# Position Group                 Metric  Coefficient Strength
#             DL 40-Yard Dash (seconds)              1.255470
#             DL       3-Cone (seconds)              0.308701
#             DL      Shuttle (seconds)              0.199412
#             DL          Hand (inches)              0.196581
#             DL        Height (inches)              0.195431
#             DL      Vertical (inches)              0.107218
#             DL    Broad Jump (inches)              0.071884
#             DL            Weight(lbs)              0.051373
#             DL      Wingspan (inches)              0.050562
#             DL           Bench (reps)              0.004717
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: OL
# ======================================================================
# Rows: 171
# Draft Tier Counts:
# Draft Tier
# Undrafted     48
# Rounds 6-7    43
# Rounds 2-3    34
# Rounds 4-5    24
# Round 1       22
# Name: count, dtype: int64
#
# 5-Fold Stratified CV Accuracy Scores:
# [0.14285714 0.32352941 0.35294118 0.32352941 0.29411765]
# Average CV Accuracy: 0.2874
# CV Accuracy Standard Deviation: 0.0746
#
# OL - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           5
# Rounds 2-3            1.00        0.11        0.20           9
# Rounds 4-5            0.15        0.50        0.23           6
# Rounds 6-7            0.40        0.55        0.46          11
# Undrafted             0.33        0.08        0.13          12
#
# Accuracy: 0.2558
# Average Ordinal Error: 1.1628
#
# Top 15 Features for OL by Absolute Coefficient Size:
#                       Feature  Coefficient
#           num__National Award    -2.672908
#    num__Combine Participation    -0.824324
#   num__40-Yard Dash (seconds)     0.752445
#            num__Hand (inches)    -0.674564
#        num__Shuttle (seconds)     0.606145
#           num__CFP Appearance    -0.552168
#           cat__Conference_ACC    -0.521615
# cat__Conference_Mountain West     0.519253
#           cat__Conference_SEC    -0.510465
#             cat__Position_IOL     0.505469
#          cat__Conference_MVFC    -0.493965
#         num__3-Cone (seconds)    -0.487190
#          cat__Conference_MEAC     0.483135
#      cat__Conference_Sun Belt    -0.423650
#              cat__Position_OT    -0.408096
#
# Combine Metric Coefficient Strength for OL:
# Position Group                 Metric  Coefficient Strength
#             OL 40-Yard Dash (seconds)              0.752445
#             OL          Hand (inches)              0.674564
#             OL      Shuttle (seconds)              0.606145
#             OL       3-Cone (seconds)              0.487190
#             OL        Height (inches)              0.063892
#             OL    Broad Jump (inches)              0.058540
#             OL      Wingspan (inches)              0.054470
#             OL            Weight(lbs)              0.032648
#             OL      Vertical (inches)              0.008584
#             OL           Bench (reps)              0.004472
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: LB
# ======================================================================
# Rows: 78
# Draft Tier Counts:
# Draft Tier
# Undrafted     25
# Rounds 4-5    20
# Rounds 6-7    17
# Rounds 2-3    13
# Round 1        3
# Name: count, dtype: int64
#
# 3-Fold Stratified CV Accuracy Scores:
# [0.5        0.23076923 0.30769231]
# Average CV Accuracy: 0.3462
# CV Accuracy Standard Deviation: 0.1132
#
# LB - Ordinal Prediction Report
# Tier             Precision      Recall    F1-Score     Support
# Round 1               0.00        0.00        0.00           1
# Rounds 2-3            0.00        0.00        0.00           3
# Rounds 4-5            0.25        0.40        0.31           5
# Rounds 6-7            0.40        0.50        0.44           4
# Undrafted             0.50        0.14        0.22           7
#
# Accuracy: 0.25
# Average Ordinal Error: 1.2
#
# Top 15 Features for LB by Absolute Coefficient Size:
#                         Feature  Coefficient
#              num__Hand (inches)    -1.366039
#           num__3-Cone (seconds)     1.074055
#          num__Shuttle (seconds)    -0.989663
#      num__Combine Participation     0.690151
#             cat__Conference_AAC    -0.610167
#         cat__Conference_Big Ten     0.586641
#   cat__Conference_Mountain West     0.582025
#             num__CFP Appearance    -0.532301
#            num__Height (inches)    -0.476772
# cat__Conference_FBS Independent    -0.438030
#             cat__Conference_ACC     0.431872
#          cat__Conference_Pac-12    -0.410623
#     num__40-Yard Dash (seconds)    -0.339818
#        cat__Conference_Sun Belt     0.301947
#  cat__Conference_Conference USA    -0.277355
#
# Combine Metric Coefficient Strength for LB:
# Position Group                 Metric  Coefficient Strength
#             LB          Hand (inches)              1.366039
#             LB       3-Cone (seconds)              1.074055
#             LB      Shuttle (seconds)              0.989663
#             LB        Height (inches)              0.476772
#             LB 40-Yard Dash (seconds)              0.339818
#             LB    Broad Jump (inches)              0.155935
#             LB            Weight(lbs)              0.135696
#             LB      Wingspan (inches)              0.087468
#             LB           Bench (reps)              0.050178
#             LB      Vertical (inches)              0.016586
#
# ======================================================================
# POSITION GROUP ORDINAL MODEL: Special Teams
# ======================================================================
# Rows: 18
# Draft Tier Counts:
# Draft Tier
# Undrafted     9
# Rounds 6-7    6
# Rounds 4-5    3
# Name: count, dtype: int64
# Skipped: not enough data or only one draft tier present.
#
# POSITION GROUP ORDINAL MODEL SUMMARY:
# Position Group  Rows  CV Accuracy Mean  CV Accuracy Std  Test Accuracy  Average Ordinal Error
#          Skill   325          0.249231         0.029832       0.256098               1.073171
#      Secondary   182          0.307958         0.084606       0.304348               0.934783
#             DL   191          0.329960         0.022469       0.187500               1.375000
#             OL   171          0.287395         0.074624       0.255814               1.162791
#             LB    78          0.346154         0.113228       0.250000               1.200000
#
# Creating overall gains chart for: Round 1
# Creating overall gains chart for: Rounds 2-3
# Creating overall gains chart for: Rounds 4-5
# Creating overall gains chart for: Rounds 6-7
# Creating overall gains chart for: Undrafted
# --- Gains Charts: Skill ---
# Creating Skill gains chart for: Round 1
# Creating Skill gains chart for: Rounds 2-3
# Creating Skill gains chart for: Rounds 4-5
# Creating Skill gains chart for: Rounds 6-7
# Creating Skill gains chart for: Undrafted
# --- Gains Charts: Secondary ---
# Creating Secondary gains chart for: Round 1
# Creating Secondary gains chart for: Rounds 2-3
# Creating Secondary gains chart for: Rounds 4-5
# Creating Secondary gains chart for: Rounds 6-7
# Creating Secondary gains chart for: Undrafted
# --- Gains Charts: DL ---
# Creating DL gains chart for: Round 1
# Creating DL gains chart for: Rounds 2-3
# Creating DL gains chart for: Rounds 4-5
# Creating DL gains chart for: Rounds 6-7
# Creating DL gains chart for: Undrafted
# --- Gains Charts: OL ---
# Creating OL gains chart for: Round 1
# Creating OL gains chart for: Rounds 2-3
# Creating OL gains chart for: Rounds 4-5
# Creating OL gains chart for: Rounds 6-7
# Creating OL gains chart for: Undrafted
# --- Gains Charts: LB ---
# Creating LB gains chart for: Round 1
# Creating LB gains chart for: Rounds 2-3
# Creating LB gains chart for: Rounds 4-5
# Creating LB gains chart for: Rounds 6-7
# Creating LB gains chart for: Undrafted
# Number of coefficients: 62
# Number of thresholds: 4
#
# Done. Ordinal models, coefficient tables, basic model, and gains charts saved.
